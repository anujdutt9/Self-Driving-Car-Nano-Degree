# %% [markdown]
# ## 3. Curvature and Perspective

# %%
import cv2
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

# %%
img = imread('./trafficSign.jpeg')

# %%
plt.imshow(img)

# %%
plt.imshow(img)
plt.plot(1152,400,'.')
plt.plot(1623,380,'.')
plt.plot(1622,608,'.')
plt.plot(1156,624,'.')

# %%
plt.imshow(img)
plt.plot(807,400,'.')
plt.plot(1152,400,'.')
plt.plot(1156,624,'.')
plt.plot(807,623,'.')

# %%
# Warp Function

def warp_image(img):
    img_size = (img.shape[1], img.shape[0])
    
    # Source Points
    src = np.float32([[1152,400],
                      [1623,380],
                      [1622,608],
                      [1156,624]])
    
    # Destination Points
     dest = np.float32([[807,400],
                      [1152,400],
                      [1156,624],
                      [807,623]])
